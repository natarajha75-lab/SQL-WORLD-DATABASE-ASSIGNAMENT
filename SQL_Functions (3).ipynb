# %% [markdown]
# **SQL Functions**

# %% [markdown]
# # Question 1 : Create a ranking of students based on score (highest first)

# %% [markdown]
# ## SQL QUERY

# %%
select  student_id,name,score,
rank() over(order by score desc)as ranking
from student_performance;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 154936.png](data:image/png;base64,...)

# %% [markdown]
# # Question 2 : Show each student's score and the previous student’s score (based on score order).

# %% [markdown]
# ## SQL QUERY

# %%
SELECT STUDENT_ID, NAME SCORE,
LAG(SCORE) OVER(order by SCORE desc) AS
PREVIOUS_SCORE
from STUDENT_PERFORMANCE;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 155327.png](data:image/png;base64,...)

# %% [markdown]
# # Question 3 : Convert all student names to uppercase and extract the month name from join_date.

# %% [markdown]
# ## SQL QUERY

# %%
select
upper(NAME) AS STUDENT_NAME,
monthname(JOIN_DATE) AS MONTH_NAME
FROM STUDENT_PERFORMANCE;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 155718.png](data:image/png;base64,...)

# %% [markdown]
# # Question 4 : Show each student's name and the next student’s attendance (ordered by attendance).

# %% [markdown]
# ## SQL QUERY

# %%
SELECT
name,
attendance,
LEAD(attendance) OVER (ORDER BY attendance) AS next_attendance
FROM Student_Performance;

# %% [markdown]
# ### OUTPUT
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Question 5 : Assign students into 4 performance groups using NTILE().

# %% [markdown]
# ## SQL QUERY

# %%
select
NAME,
SCORE,
ntile(4) over(order by SCORE desc) AS PERFORMANCE_GROUP
from STUDENT_PERFORMANCE;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 160908.png](data:image/png;base64,...)

# %% [markdown]
# # Question 6 : For each course, assign a row number based on attendance (highest first).

# %% [markdown]
# ## SQL QUERY

# %%
select
COURSE,
NAME,
attendance,
row_number() over (partition by COURSE order by attendance desc) AS ROW_NUM
FROM STUDENT_PERFORMANCE;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 161333.png](data:image/png;base64,...)

# %% [markdown]
# Question 7 : Calculate the number of days each student has been enrolled (from join_date to today).
# (Assume current date = '2025-01-01')

# %% [markdown]
# ## SQL QUERY

# %%
select
NAME,
JOIN_DATE,
datediff('2025-01-01', JOIN_DATE) AS DAYS_ENROLLED
FROM STUDENT_PERFORMANCE;

# %% [markdown]
# ###  OUTPUT
# ![Screenshot 2026-06-14 161744.png](data:image/png;base64,...)

# %% [markdown]
# #Question 8 : Format join_date as “Month Year” (e.g., “June 2023”)

# %% [markdown]
# ## SQL QUERY

# %%
select
NAME,
date_format(JOIN_DATE,'%M %Y') AS MONTH_YEAR
FROM STUDENT_PERFORMANCE;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 162025.png](data:image/png;base64,...)

# %% [markdown]
# #Question 9 : Replace the city ‘Mumbai’ with ‘MUM’ for display purposes.

# %% [markdown]
# ## SQL QUERY

# %%
select
NAME,
replace(CITY,'mumbai','MUM') AS CITY
FROM STUDENT_PERFORMANCE;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 162512.png](data:image/png;base64,...)

# %% [markdown]
# # Question 10 : For each course, find the highest score using FIRST_VALUE().

# %% [markdown]
# ## SQL QUERY

# %%
select
COURSE,
NAME,
SCORE,
first_value(score) over
(partition by course order by score desc) as
highest_score
from student_performance;

# %% [markdown]
# ### OUTPUT
# ![Screenshot 2026-06-14 163337.png](data:image/png;base64,...)

# %% [markdown]
# #
